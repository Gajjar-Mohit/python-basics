# %%
print("Mohit is learning liner regression")
# Out:
# Mohit is learning liner regression

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel('./dataset.xlsx')

# %%
df
# Out:
#     Table  Value
# 0       1     18
# 1       2     36
# 2       3     54
# 3       4     72
# 4       5     90
# 5       6    108
# 6       7    126
# 7       8    144
# 8       9    162
# 9      10    180
# 10     11    198
# 11     12    216
# 12     13    234
# 13     14    252

# %%
from matplotlib import pyplot as plt

# first import the dataset and analyse with matplotlib and cborn garphically

# %%
plt.scatter(df['Table'], df['Value'])

# %%
from sklearn.model_selection import train_test_split

X_train, x_test, Y_train, y_test = train_test_split(df[['Table']], df['Value'])

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_probe = model.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 1.0
